# %%
import pandas as pd
import gmaps
from config import api_key
# Import File (CSV)
latlon_df=pd.read_csv("../Resources/states_lat_lon.csv")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
latlon_df.head()
# Out:
#   states.csv Unnamed: 1   Unnamed: 2 Unnamed: 3
# 0        NaN        NaN          NaN        NaN
# 1      state   latitude    longitude       name
# 2         AK  63.588753  -154.493062     Alaska
# 3         AL  32.318231   -86.902298    Alabama
# 4         AR   35.20105   -91.831833   Arkansas

# %%
latlon_df1=latlon_df.drop([0,1])

# %%
latlon_df1
# Out:
#    states.csv Unnamed: 1   Unnamed: 2            Unnamed: 3
# 2          AK  63.588753  -154.493062                Alaska
# 3          AL  32.318231   -86.902298               Alabama
# 4          AR   35.20105   -91.831833              Arkansas
# 5          AZ  34.048928  -111.093731               Arizona
# 6          CA  36.778261  -119.417932            California
# 7          CO  39.550051  -105.782067              Colorado
# 8          CT  41.603221   -73.087749           Connecticut
# 9          DC  38.905985   -77.033418  District of Columbia
# 10         DE  38.910832    -75.52767              Delaware
# 11         FL  27.664827   -81.515754               Florida
# 12         GA  32.157435   -82.907123               Georgia
# 13         HI  19.898682  -155.665857                Hawaii
# 14         IA  41.878003   -93.097702                  Iowa
# 15         ID  44.068202  -114.742041                 Idaho
# 16         IL  40.633125   -89.398528              Illinois
# 17         IN  40.551217   -85.602364               Indiana
# 18         KS  39.011902   -98.484246                Kansas
# 19         KY  37.839333   -84.270018              Kentucky
# 20         LA  31.244823   -92.145024             Louisiana
# 21         MA  42.407211   -71.382437         Massachusetts
# 22         MD  39.045755   -76.641271              Maryland
# 23         ME  45.253783   -69.445469                 Maine
# 24         MI  44.314844   -85.602364              Michigan
# 25         MN  46.729553     -94.6859             Minnesota
# 26         MO  37.964253   -91.831833              Missouri
# 27         MS  32.354668   -89.398528           Mississippi
# 28         MT  46.879682  -110.362566               Montana
# 29         NC  35.759573     -79.0193        North Carolina
# 30         ND  47.551493  -101.002012          North Dakota
# 31         NE  41.492537   -99.901813              Nebraska
# 32         NH  43.193852   -71.572395         New Hampshire
# 33         NJ  40.058324   -74.405661            New Jersey
# 34         NM   34.97273  -105.032363            New Mexico
# 35         NV   38.80261  -116.419389                Nevada
# 36         NY  43.299428   -74.217933              New York
# 37         OH  40.417287   -82.907123                  Ohio
# 38         OK  35.007752   -97.092877              Oklahoma
# 39         OR  43.804133  -120.554201                Oregon
# 40         PA  41.203322   -77.194525          Pennsylvania
# 41         PR  18.220833   -66.590149           Puerto Rico
# 42         RI  41.580095   -71.477429          Rhode Island
# 43         SC  33.836081   -81.163725        South Carolina
# 44         SD  43.969515   -99.901813          South Dakota
# 45         TN  35.517491   -86.580447             Tennessee
# 46         TX  31.968599   -99.901813                 Texas
# 47         UT   39.32098  -111.093731                  Utah
# 48         VA  37.431573   -78.656894              Virginia
# 49         VT  44.558803   -72.577841               Vermont
# 50         WA  47.751074  -120.740139            Washington
# 51         WI   43.78444   -88.787868             Wisconsin
# 52         WV  38.597626   -80.454903         West Virginia
# 53         WY  43.075968  -107.290284               Wyoming

# %%
#latlon_df=latlon_df.set_index(['Unnamed: 3'])

# %%
latlon_df=latlon_df.rename(columns={'Unnamed: 1': 'Latitude','Unnamed: 2': 'Longitude','Unnamed: 3':'state'})

# %%
latlon_df=latlon_df[['Latitude','Longitude','state']]
latlon_df.head()
# Out:
#     Latitude    Longitude     state
# 0        NaN          NaN       NaN
# 1   latitude    longitude      name
# 2  63.588753  -154.493062    Alaska
# 3  32.318231   -86.902298   Alabama
# 4   35.20105   -91.831833  Arkansas

# %%
locations = latlon_df[["Latitude", "Longitude"]]

# %%
breweries_df=pd.read_csv('../Resources/breweries.csv')
breweries_df
# Out:
#                                       id                             name  \
# 0             10-56-brewing-company-knox            10-56 Brewing Company
# 1              10-barrel-brewing-co-bend             10 Barrel Brewing Co
# 2            10-barrel-brewing-co-bend-2             10 Barrel Brewing Co
# 3     10-barrel-brewing-co-bend-pub-bend  10 Barrel Brewing Co - Bend Pub
# 4       10-barrel-brewing-co-boise-boise     10 Barrel Brewing Co - Boise
# ...                                  ...                              ...
# 7792  zuni-street-brewing-company-denver      Zuni Street Brewing Company
# 7793           zwanzigz-brewing-columbus                 ZwanzigZ Brewing
# 7794        zwei-brewing-co-fort-collins                  Zwei Brewing Co
# 7795             zydeco-brew-werks-tampa                Zydeco Brew Werks
# 7796         zymurgy-brew-works-torrance               Zymurgy Brew Works
#
#      brewery_type                       street address_2 address_3  \
# 0           micro                400 Brown Cir       NaN       NaN
# 1           large                62970 18th St       NaN       NaN
# 2           large  1135 NW Galveston Ave Ste B       NaN       NaN
# 3           large             62950 NE 18th St       NaN       NaN
# 4           large             826 W Bannock St       NaN       NaN
# ...           ...                          ...       ...       ...
# 7792        micro              2355 W 29th Ave       NaN       NaN
# 7793      brewpub           1038 Lafayette Ave       NaN       NaN
# 7794        micro      4612 S Mason St Ste 120       NaN       NaN
# 7795      brewpub               1902 E 7th Ave       NaN       NaN
# 7796        micro         22755 Hawthorne Blvd       NaN       NaN
#
#               city       state county_province postal_code  \
# 0             Knox     Indiana             NaN       46534
# 1             Bend      Oregon             NaN  97701-9847
# 2             Bend      Oregon             NaN  97703-2465
# 3             Bend      Oregon             NaN       97701
# 4            Boise       Idaho             NaN  83702-5857
# ...            ...         ...             ...         ...
# 7792        Denver    Colorado             NaN  80211-3753
# 7793      Columbus     Indiana             NaN  47201-5756
# 7794  Fort Collins    Colorado             NaN  80525-3794
# 7795         Tampa     Florida             NaN  33605-3810
# 7796      Torrance  California             NaN  90505-3613
#
#                            website_url       phone           created_at  \
# 0                                  NaN  6308165790  2018-07-24 01:33:21
# 1              http://www.10barrel.com  5415851007  2018-07-24 01:34:04
# 2                                  NaN  5415851007  2018-07-24 01:34:04
# 3                                  NaN  5415851007  2018-07-24 01:34:04
# 4              http://www.10barrel.com  2083445870  2018-07-24 01:33:17
# ...                                ...         ...                  ...
# 7792  http://www.zunistreetbrewing.com  3038626525  2018-07-24 01:33:09
# 7793           http://www.zwanzigz.com  8123760200  2018-07-24 01:33:23
# 7794  http://www.zweibruderbrewing.com  9702232482  2018-07-24 01:33:09
# 7795                               NaN  8132524541  2018-07-24 01:33:15
# 7796   http://www.zymurgybrewworks.com  3106502474  2018-07-24 01:33:03
#
#                updated_at        country   longitude   latitude  tags
# 0     2018-08-24 00:32:25  United States  -86.627954  41.289715   NaN
# 1     2018-08-11 21:39:09  United States         NaN        NaN   NaN
# 2     2018-08-11 21:39:09  United States         NaN        NaN   NaN
# 3     2018-08-24 15:45:44  United States -121.280954  44.091211   NaN
# 4     2020-10-11 17:00:13  United States -116.202929  43.618516   NaN
# ...                   ...            ...         ...        ...   ...
# 7792  2018-08-24 00:25:18  United States -105.015409  39.758593   NaN
# 7793  2018-08-24 00:33:42  United States  -85.918836  39.208657   NaN
# 7794  2018-08-11 21:36:45  United States         NaN        NaN   NaN
# 7795  2018-08-24 00:28:55  United States  -82.437832  27.960344   NaN
# 7796  2018-08-24 00:05:10  United States -118.352467  33.863537   NaN
#
# [7797 rows x 18 columns]

# %%
breweries_df=breweries_df['state']

# %%
brewery_count=breweries_df.value_counts()
brewery_count.dtypes
# Out:
# dtype('int64')

# %%
merged_set=pd.merge(latlon_df,breweries_df,on='state')
merged_set.dropna()
# Out:
#        Latitude    Longitude    state
# 10    63.588753  -154.493062   Alaska
# 11    63.588753  -154.493062   Alaska
# 12    63.588753  -154.493062   Alaska
# 13    63.588753  -154.493062   Alaska
# 14    63.588753  -154.493062   Alaska
# ...         ...          ...      ...
# 7791  43.075968  -107.290284  Wyoming
# 7792  43.075968  -107.290284  Wyoming
# 7793  43.075968  -107.290284  Wyoming
# 7794  43.075968  -107.290284  Wyoming
# 7795  43.075968  -107.290284  Wyoming
#
# [7786 rows x 3 columns]

# %%
state_count=merged_set['state'].value_counts()
#locations = merged_set[['Latitude','Longitude']]
#len(state_count)
#display(locations)
locations=locations.drop([0,1])
len(state_count)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-2fab8adec6da> in <module>
#       3 #len(state_count)
#       4 #display(locations)
# ----> 5 locations=locations.drop([0,1])
#       6 len(state_count)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: '[0 1] not found in axis'

# %%
display(locations)
locations=locations.drop[41]
# Out:
#      Latitude    Longitude
# 2   63.588753  -154.493062
# 3   32.318231   -86.902298
# 4    35.20105   -91.831833
# 5   34.048928  -111.093731
# 6   36.778261  -119.417932
# 7   39.550051  -105.782067
# 8   41.603221   -73.087749
# 9   38.905985   -77.033418
# 10  38.910832    -75.52767
# 11  27.664827   -81.515754
# 12  32.157435   -82.907123
# 13  19.898682  -155.665857
# 14  41.878003   -93.097702
# 15  44.068202  -114.742041
# 16  40.633125   -89.398528
# 17  40.551217   -85.602364
# 18  39.011902   -98.484246
# 19  37.839333   -84.270018
# 20  31.244823   -92.145024
# 21  42.407211   -71.382437
# 22  39.045755   -76.641271
# 23  45.253783   -69.445469
# 24  44.314844   -85.602364
# 25  46.729553     -94.6859
# 26  37.964253   -91.831833
# 27  32.354668   -89.398528
# 28  46.879682  -110.362566
# 29  35.759573     -79.0193
# 30  47.551493  -101.002012
# 31  41.492537   -99.901813
# 32  43.193852   -71.572395
# 33  40.058324   -74.405661
# 34   34.97273  -105.032363
# 35   38.80261  -116.419389
# 36  43.299428   -74.217933
# 37  40.417287   -82.907123
# 38  35.007752   -97.092877
# 39  43.804133  -120.554201
# 40  41.203322   -77.194525
# 42  41.580095   -71.477429
# 43  33.836081   -81.163725
# 44  43.969515   -99.901813
# 45  35.517491   -86.580447
# 46  31.968599   -99.901813
# 47   39.32098  -111.093731
# 48  37.431573   -78.656894
# 49  44.558803   -72.577841
# 50  47.751074  -120.740139
# 51   43.78444   -88.787868
# 52  38.597626   -80.454903
# 53  43.075968  -107.290284
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-d3bf51be1d23> in <module>
#       1 display(locations)
# ----> 2 locations=locations.drop[41]
#
# TypeError: 'method' object is not subscriptable

# %%
# state_count=state_count #.astype(float)
# state_count=state_count.reset_index()
# variable = state_count['state']
# variable
count=state_count['state']
count
# Out:
# 0     896.0
# 1     429.0
# 2     422.0
# 3     415.0
# 4     375.0
# 5     343.0
# 6     343.0
# 7     312.0
# 8     307.0
# 9     303.0
# 10    291.0
# 11    254.0
# 12    249.0
# 13    217.0
# 14    182.0
# 15    163.0
# 16    162.0
# 17    141.0
# 18    124.0
# 19    115.0
# 20    114.0
# 21    109.0
# 22    108.0
# 23     99.0
# 24     92.0
# 25     92.0
# 26     87.0
# 27     83.0
# 28     76.0
# 29     72.0
# 30     64.0
# 31     59.0
# 32     58.0
# 33     53.0
# 34     51.0
# 35     51.0
# 36     47.0
# 37     45.0
# 38     45.0
# 39     44.0
# 40     43.0
# 41     41.0
# 42     32.0
# 43     30.0
# 44     28.0
# 45     26.0
# 46     23.0
# 47     23.0
# 48     16.0
# 49     16.0
# 50     16.0
# Name: state, dtype: float64

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=count, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-1694a4cd7608> in <module>
#       3
#       4 # Create heat layer
# ----> 5 heat_layer = gmaps.heatmap_layer(locations, weights=count,
#       6                                  dissipating=False, max_intensity=10,
#       7                                  point_radius=1)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gmaps/heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     267     )
#     268     if is_weighted:
# --> 269         return WeightedHeatmap(**widget_args)
#     270     else:
#     271         return Heatmap(**widget_args)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py in __init__(self, *args, **kwargs)
#    1078                 else:
#    1079                     # passthrough args that don't set traits to super
# -> 1080                     super_kwargs[key] = value
#    1081         try:
#    1082             super(HasTraits, self).__init__(*super_args, **super_kwargs)
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# ~/opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1212                 for changes in cache.values():
#    1213                     for change in changes:
# -> 1214                         self.notify_change(change)
#    1215
#    1216     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1225     def notify_change(self, change):
#    1226         """Notify observers of a change event"""
# -> 1227         return self._notify_observers(change)
#    1228
#    1229     def _notify_observers(self, event):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py in _notify_observers(self, event)
#    1262                 c = getattr(self, c.name)
#    1263
# -> 1264             c(event)
#    1265
#    1266     def _add_notifiers(self, handler, name, type):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gmaps/heatmap.py in _calc_bounds(self, change)
#     188     def _calc_bounds(self, change):
#     189         data = change['new']
# --> 190         self.set_bounds(data)
#     191
#     192
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gmaps/heatmap.py in set_bounds(self, data)
#      69         latitudes = [row[0] for row in data]
#      70         longitudes = [row[1] for row in data]
# ---> 71         min_latitude, max_latitude = self._latitude_bounds(latitudes)
#      72         min_longitude, max_longitude = self._longitude_bounds(longitudes)
#      73         self.data_bounds = [
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gmaps/heatmap.py in _latitude_bounds(self, latitudes)
#      77
#      78     def _latitude_bounds(self, latitudes):
# ---> 79         return bounds.latitude_bounds(latitudes)
#      80
#      81     def _longitude_bounds(self, longitudes):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gmaps/bounds.py in latitude_bounds(latitudes)
#      13     Estimate latitude bound with 2*sample standard deviation
#      14     """
# ---> 15     if max(latitudes) - min(latitudes) < 2.0*EPSILON:
#      16         lower_bound = latitudes[0] - EPSILON
#      17         upper_bound = latitudes[0] + EPSILON
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
